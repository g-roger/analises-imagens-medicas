# %% [markdown]
# <a href="https://colab.research.google.com/github/g-roger/analises-imagens-medicas/blob/main/analise_imagens_medicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MBA FIAP Inteligência Artificial & Machine Learning
#
# ## Visão Computacional: Análise de Imagens Médicas
#
# > Atenção: este notebook foi desenhado para funcionar no **Google Collab**. Se pretende executar localmente prefira a versão local deste notebook, sem o sufixo ```-collab```.
#
#
# ## 1. Introdução
#
# As tecnologias de imagens médicas estão cada vez mais integradas aos sistemas de visão computacional, incluindo as imagens de raio-x.
#
# Modelos de equipamentos modernos geram imagens digitais deste tipo de exame, proporcionando análises mais completas e menos _ad-hoc_, com isso algumas pré-análises podem ser realizadas por aplicações baseadas em inteligência artificial para confirmar ou sugerir diagnósticos ao profissional responsável pelo exame.
#
# No campo dos diagósticos por raios-x, a pnenumonia é uma das enfermidades onde seu uso é um dos mais aplicados para determinar o curso de tratamento.
#
# <p align="center">
#     <img src="https://github.com/michelpf/fiap-ml-visao-computacional-capstone-alternative/blob/master/projeto-final/imagens/NORMAL2-IM-1422-0001.jpeg?raw=1">
# </p>
#
# ## 2. Instruções
#
# Este projeto final tem como objetivo explorar os conhecimentos adquiridos nas aulas práticas.
#
# Por meio de uma trilha guiada, iremos constuir um modelo que seja capaz de classificar imagens de raio-x para determinar se a determinada pessoa está com alguma condição que necessita maiores cuidados.
#
# De acordo com as imagens disponíveis para o treinamento e validação, será de critério do grupo selecionar as quantidades ideais ou até mesmo pré-processar as imagens para obter o melhor resultado, nos principais indicadores de performance, como precisão, sensibilidade e pontuação F1.
#
# Este projeto poderá ser feita por grupos de até 4 pessoas.
# Caso este projeto seja substitutivo, deverá ser realizado por apenas uma pessoa.
#
# | Nome dos Integrantes     | RM             | Turma |
# | :----------------------- | :------------- | :-----: |
# | Gabriel Roger            | RM 340399      | `20IA` |
# | Integrante 2             | RM 12345       | `1IA` |
# | Integrante 3             | RM 12345       | `1IA` |
# | Integrante 4             | RM 12345       | `1IA` |
#
# Por ser um projeto guiado, fique atento quando houver as marcações **Implementação** indica que é necessário realizar alguma implementação em Python no bloco a seguir onde há a inscrição ```##IMPLEMENTAR``` e **Resposta** indica que é esperado uma resposta objetiva relacionado a algum questionamento.
#
# **Cada grupo pode utilizar nas respostas objetivas quaisquer itens necessários que enriqueçam seu ponto vista, como gráficos, fotos e, até mesmo, trechos de código-fonte.**
#
# Pode-se utilizar quantos blocos forem necessários para realizar determinadas implementações ou utilizá-las para justificar as respostas. Não é obrigatório utilizar somente o bloco indicado.
#
# Ao final não se esqueça de subir os arquivos do projeto nas contas do GitHub de cada membro, ou subir na do representante do grupo e os membros realizarem o fork do projeto.
#
# A avaliação terá mais ênfase nos seguintes tópicos de desenvolvimento do projeto:
#
# 1. __Pré-Processamento__
# 2. __Classificação__
# 3. __Performance__
# 4. __Conclusões Finais__

# %% [markdown]
# ## 3.1 Detalhe do problema: a pneunomia
#
# Fonte: [artigo](https://drauziovarella.uol.com.br/doencas-e-sintomas/pneumonia) do Dr. Drauzio Varella.
#
# Pneumonias são infecções que se instalam nos pulmões, órgãos duplos localizados um de cada lado da caixa torácica. Podem acometer a região dos alvéolos pulmonares onde desembocam as ramificações terminais dos brônquios e, às vezes, os interstícios (espaço entre um alvéolo e outro).
#
# Basicamente, pneumonia é provocada pela penetração de um agente infeccioso ou irritante (bactérias, vírus, fungos e por reações alérgicas) no espaço alveolar, onde ocorre a troca gasosa. Esse local deve estar sempre muito limpo, livre de substâncias que possam impedir o contato do ar com o sangue.
#
# Exame clínico, auscultação dos pulmões e radiografias de tórax são recursos essenciais para o diagnóstico de pneumonia.
#
# <p align="center">
#     <img src="https://github.com/michelpf/fiap-ml-visao-computacional-capstone-alternative/blob/master/projeto-final/imagens/pneumonia.jpeg?raw=1">
# </p>

# %% [markdown]
# ## 3.2 Diagnóstico por raio-x

# %% [markdown]
# O exame de raio-x traz diferenças em cada tipo de diagnóstico, sendo considerado os seguintes grupos de análise: **normal** (ou controle) onde não há nenhuma condição de infeção, **bacterial pneumonia** (pneumonia bacteriana) que representa a condição de infecção bacteriana e **viral pneumonia** que indica a condição de infecção vira.

# %% [markdown]
# <p align="center">
# <img src="https://github.com/michelpf/fiap-ml-visao-computacional-capstone-alternative/blob/master/projeto-final/imagens/raiox.png?raw=1" height="60%" width="60%">
# </p>

# %% [markdown]
# As imagens de controle não são mais brancas ao centro que é onde fica o coração. Já nas imagens com pneumonia é possível notar regiões brancas ao redor dos pulmões, que é como o exame identifica as secreções responsáveis pela infeçcão.
#
# Quando mais regiões brancas ao redor do pulmão mais severa é a inflamação e menos se observa dos detalhes dos pulmões, ficando um pouco esmaecido diante desta condição.

# %% [markdown]
# ## 4.1 Problema
#
# Construir um classificador utilizando _transfer learning_ para identificar as seguintes classes: **controle**, **pneumonia bacteriana** e **pneumonia viral**.
#
# Para construir este classificador, utilize o dataset do [Kaggle Chest Ray Pneumonia](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia) e organize os dados de forma a separar em cada uma das classes que já estão definidas no diretório ```raiox```, sendo ```controle``` para as imagens normais (sem inflamação), ```bacteria``` para as imagens de pneumonia bacteriana e ```viral``` para as imagens de pneumonia viral.
#
# Determine a quantidade de imagens a serem treinadas e validadas. Utiliza pelo menos, 100 imagens para cada classe.
#
# Compare os resultados com pelo menos 3 classificadores, obtendo os valores de **precisão (precision)**, **sensibilidade (recall)** e **pontuação F1 (F1 Score)**. No guia abaixo, foi indicado os seguintes modelos: ResNet50, VGG16 e VGG19.
#
# >Importante: a escolha do número de imagens devem ser o suficiente para alcançar o valor de **precisão** mínima de 70%.
# Note que as imagens de pneumonia bacteria e viral estão misturadas dentro da pasta ```PNEUMONIA```. É necessário separar as imagens manualmente tendo como base o sufixo. As imagens que terminal com ```_virus``` se referem a pneumoria viral e as que terminam com ```_bacteria``` se referem a pneumonia bacteriana.
#
# A construção do modelo será utilizada o framework Keras.

# %% [markdown]
# **Pergunta**: Qual o número de imagens que foram selecionadas para cada classe?

# %% [markdown]
# **Resposta**:

# %% [markdown]
# ## 4.2 Componentes obrigatórios
#
# Todas as bibliotecas já estão instaladas no Google Colab.
#
# * Keras
# * Tensorflow
# * Pillow
# * Matplotlib

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %matplotlib inline

from tensorflow.keras.models import Sequential, load_model, model_from_json
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, ResNet50, VGG19, ResNet152
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras import Model, layers
from tensorflow.keras import optimizers

import tensorflow.keras.backend as K

# %% [markdown]
# ## 4.3 Carregando imagens de treinamento e validação
#
# Selecione a melhor divisão entre dados de treinamento e validação. O número deverá ser representado em número fracionário, 5% equivale a 0.05, por exemplo.

# %% [markdown]
# > Você pode _montar_ o drive do Google Drive se precisar e quiser armazenar as imagens nesta plataforma. Como o Colab é efêmero, se você copiar os arquivos para o ambiente eles serão apagados depois do fim da sessão. Acesse [esta](https://medium.com/@maxwellcsm/colaboratory-acessando-os-arquivos-do-google-drive-d08ef9157dbf) referência para saber mais como o recurso funciona, inclusive recomenda-se essa abordagem de montar o próprio Google Drive.
#
# Se não for utilizar o Google Drive, crie as pastas que serão utilizadas para armazenar as imagens.

# %% [markdown]
# ### 4.3.1 Utilizando Google Drive
#
# Se usar o Google Drive para armazenar as imagens utilize o comando abaixo para montar seu drive.
# Você pode navegar pelas pastas pelo painel ao lado.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 4.3.2 Utilizando o armazenamento efêmero
#
# Se optar pelo armazenamento efêmero você precisa enviar os arquivos de imagens (arrastar e soltar) para as pastas que deverão ser criadas pelo comando a seguir.

# %%
# !mkdir raiox/
# !mkdir raiox/normal
# !mkdir raiox/pneumonia_bacteriana
# !mkdir raiox/pneumonia_viral

# %% [markdown]
# Defina o nome da pasta onde contém as sub-pastas referente aos 3 tipos de classe. Se optar pelo armazenamento efêmero a pasta será ```raiox```. Se optar pelo Google Drive, indique o caminho da pasta.

# %%
divisao_treino_validacao = 0.30
nome_pasta_raiz_imagens = '/content/drive/MyDrive/Estudos/FIAP/Visão Computacional/raiox'

# %% [markdown]
# O caminho abaixo da pasta ```raiox``` pode ser alterado caso você opte por utilizar uma pasta específica do seu Google Drive. Neste caso, certifique que dentro delas tem as sub-pastas referentes as imagens normal, pneumonia bacteriana e viral.

# %%
train_datagen = ImageDataGenerator(validation_split=divisao_treino_validacao)

train_generator = train_datagen.flow_from_directory(
    nome_pasta_raiz_imagens,
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224),
    subset="training")
# Out:
# Found 404 images belonging to 3 classes.

# %%
val_generator = train_datagen.flow_from_directory(
    nome_pasta_raiz_imagens,
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224),
    subset="validation")
# Out:
# Found 170 images belonging to 3 classes.

# %%
train_generator.class_indices, val_generator.class_indices
# Out:
# ({'normal': 0, 'pneumonia_bacteriana': 1, 'pneumonia_viral': 2},
#  {'normal': 0, 'pneumonia_bacteriana': 1, 'pneumonia_viral': 2})

# %% [markdown]
# ## 4.4 Modelos de transfer learning
#
# O Keras já possui classes especializadas para os seguintes modelos de deep-learning treinados com o conjunto de dados [ImageNet](http://www.image-net.org/):
#
# * Xception
# * VGG16
# * VGG19
# * ResNet50
# * InceptionV3
# * InceptionResNetV2
# * MobileNet
# * DenseNet
# * NASNet
# * MobileNetV2
#
# Mais detalhes, veja na [documentação do Keras](https://keras.io/applications/).

# %% [markdown]
# Para este estudo, vamos utilizar para avaliação as seguintes arquiteturas: ResNet50, VGG15 e VGG19.

# %% [markdown]
# ## 4.5 Indicadores de desempenho
#
# O Keras não possui os indicadores de desempenho como precisão, sensibilidade e pontuação f1 por padrão, portanto precisamos implementar externamente.

# %%
def recall_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_score(y_true, y_pred):
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## **Os resultados do modelo mudaram com base na sua execução pois não definimos a semente, os resultados inseridos nas respostas são com base nas primeiras execuções**

# %% [markdown]
# ### 4.5.1 Arquitetura ResNet50

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do ResNet50? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# Resposta:
#
# ### Deep Neural Networks e Arquitetura RESNET50

# %% [markdown]
# Com base nos estudos relacionados a Deep Neural Networks, notamos que são ótimos para identificar as features dos modelos, a maior questão é sobre o aumento de camadas conseguir ter uma ótima performance.
#
# Surgiu-se assim alguns problemas com o aumento das camadas, é de se imaginar que no  processo de treino seja sempre overffiting, porém no caso dos modelos com o número de camadas elevadas não foi isso, mas sim a acurácia ficar saturada, problemas de gradiente de fuga e reduzir os acertos, resultando em erros de treino dos modelos.
#
# Encontramos um gráfico que demonstrava o problema para entendimento do surgimento das RESNETS:
#
# ![image.png](data:image/png;base64,...)
#
# Nessa imagem notamos como o modelo com o aumento das camadas resultam em erros de treino e teste.
#
# A ResNet resolve o problema do aumento das camadas para performar de uma melhor forma e ter uma acurácia que comparado a menores camadas ser de fato superior.
#
# A ResNet50 pode trabalhar com até 50 camadas de redes neurais para resolver problemas de visão computacional. O objetivo é o modelo ajudar no treinamento dos dados.
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Os blocos de identidade e convolução são combinados para criar um modelo resnet50.
#
# A arquitetura funciona em 5 estágios, cada qual com seu bloco de convolução e identidade do bloco.
# Cada bloco de identidade possui 3 camadas de convolução.
#
# Através de pesquisas um fato curioso é que a resnet50 tem mais de 23 milhões de parâmetros treináveis.
#
# O modelo usa conexão skip para adicionar a saída de uma camada anterior a uma camada posterior. Isso ajuda a mitigar o problema do gradiente de fuga.
#
# Um grande problema através de nossos estudos é que apesar da resnet performar de uma maneira eficaz para várias aplicações, essa rede geralmente precisa de semanas para treinamento, fazendo com que alguns cenários do mundo real faça substituir para outros modelos.
#
# Uma forma de usar a resnet no mercado é a mesma como ensemble com outras redes.
#
#
# Para entender um pouco sobre redes resíduais utilizamos esses artigos:
#
# https://towardsdatascience.com/resnets-why-do-they-perform-better-than-classic-convnets-conceptual-analysis-6a9c82e06e53uma-visao-geral-da-resnet-e-suas-variantes/
#
# https://towardsdatascience.com/an-overview-of-resnet-and-its-variants-5281e2f56035
#
# https://www.analyticsvidhya.com/blog/2021/08/all-you-need-to-know-about-skip-connections/
#
# Nesse notebook: https://github.com/g-roger/fork-deep-learning/blob/master/resnet_keras/Residual_Network_Keras.ipynb
# conseguimos entender como podemos organizar com keras um usando resnet50

# %% [markdown]
# A técnica de transfer learning consiste de utilizar o mesmo modelo e treiná-lo para outas imagens. Por tal motivo, excluímos a última camada para modelar com as classes que definimos, ou seja, **controle**, **bacteriana** e **viral**.

# %% [markdown]
# Informe a quantidade de classes a serem classificadas.

# %%
qtde_classes = len(train_generator.class_indices)

# %%
conv_base = ResNet50(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv1_pad (ZeroPadding2D)      (None, None, None,   0           ['input_5[0][0]']
#                                 3)
#
#  conv1_conv (Conv2D)            (None, None, None,   9472        ['conv1_pad[0][0]']
#                                 64)
#
#  conv1_bn (BatchNormalization)  (None, None, None,   256         ['conv1_conv[0][0]']
#                                 64)
#
#  conv1_relu (Activation)        (None, None, None,   0           ['conv1_bn[0][0]']
#                                 64)
#
#  pool1_pad (ZeroPadding2D)      (None, None, None,   0           ['conv1_relu[0][0]']
#                                 64)
#
# ...

# %%
optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %% [markdown]
# O número de épocas define quantas vezes o modelo irá treinar e validar o erro, assim ajustando os pesos para melhor convergência.
# Escolha o número adequado de épocas para alcançarmos pelo menos **70% de precisão de validação**.

# %%
qtde_epocas = 7

# %%
history = model.fit(train_generator, epochs=qtde_epocas, validation_steps=5, steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Epoch 1/7
# 5/5 [==============================] - 10s 2s/step - loss: 1.0812 - precision_score: 0.5934 - recall_score: 0.5125 - f1_score: 0.5439 - val_loss: 0.7157 - val_precision_score: 0.7721 - val_recall_score: 0.7563 - val_f1_score: 0.7639
# Epoch 2/7
# 5/5 [==============================] - 5s 1s/step - loss: 0.7580 - precision_score: 0.7742 - recall_score: 0.7563 - f1_score: 0.7649 - val_loss: 0.4582 - val_precision_score: 0.8440 - val_recall_score: 0.8062 - val_f1_score: 0.8244
# Epoch 3/7
# 5/5 [==============================] - 6s 1s/step - loss: 0.4228 - precision_score: 0.8690 - recall_score: 0.8288 - f1_score: 0.8479 - val_loss: 0.4041 - val_precision_score: 0.8681 - val_recall_score: 0.8313 - val_f1_score: 0.8488
# Epoch 4/7
# 5/5 [==============================] - 6s 1s/step - loss: 0.3510 - precision_score: 0.8619 - recall_score: 0.8562 - f1_score: 0.8590 - val_loss: 0.5696 - val_precision_score: 0.8000 - val_recall_score: 0.8000 - val_f1_score: 0.8000
# Epoch 5/7
# ...

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# Para entendermos as métricas é preciso estar familiarizado com a matriz de confusão.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Resposta**:
#
# O modelo convergiu bem, pois conseguimos notar que precisão, sensibilidade e f1_score tendem a crescer no gráfico enquanto a perda diminuir.
#
# Quando treinamos e testamos um modelo é interessate analisar esses gráficos para decifrar um bom "fit" para o modelo. É possível notar se possuí underfitting ou overfitting, por conta de algum viés ou variancia.
#
# Abaixo estamos interpretando cada um dos resultados.
#
# Precisão:
#
# A precisão é a razão entre os Verdadeiros Positivos e todos os positivos.
# Como codificado acima. dentre todas as classificações de classe Positivo que o modelo fez, quantas estão corretas
#
# No nosso modelo a precisão foi de 92%.
#
# **Nesse caso como estamos estudando qual pode ser o sintoma através de imagens de pulmão, classificar qual pode ser a situação do paciente é preciso que o modelo esteja correto, porém a situação do falso negativo (pessoa sem pneumonia ou covid) serem classificadas com a doença é arriscado.**
#
# **Sensibilidade:**
#
# O cálculo do Recall já é os verdadeiros positivos dividido pela soma dos verdadeiros positivos e falso negativos.
# entre todas as situações de classe Positivo como valor esperado, quantas estão corretas.
#
# **Nesse caso olhar para o Recall é mais interessante para nós, pois é uma situação onde falso negativos são considerados mais prejudiciais que os falsos positivos.O modelo deve encontrar todos os pacientes com pneumonia ou covid, mesmo que classifique alguns saudáveis como com a doença (situação de Falso Positivo) no processo. Ou seja, o modelo deve ter alto recall/sensibilidade, pois classificar pacientes doentes como saudáveis pode ser uma perigoso.**
#
# No nosso modelo a sensibilidade foi de 91%.
#
# **F1-SCORE**
#
# É uma média harmônica entre precisão e sensibilidade (precision e recall). É uma forma de observar apenas uma métrica.
# Se o F1-Score está baixo, a precisão e sensibilidade também estão.
#
#
# No nosso modelo a f1-score foi de 91%.
#
#
# **LOSS**
# A perca é medir o quanto o valor está longe do valor verdadeiro.
# Com ela no gráfico caindo é possível validarmos os erros do nosso modelo.
#
# Observamos sempre as métricas de validação nesse estudo.
#
#
# Tanto o treino e teste estão próximos, isso mostra que nosso modelo não está com underfitting ou overfitting

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:
#
# 5/5 [==============================] - 8s 2s/step - loss: 0.2214 - precision_score: 0.9308 - recall_score: 0.9250 - f1_score: 0.9279 - val_loss: 0.2895 - val_precision_score: 0.9058 - val_recall_score: 0.9000 - val_f1_score: 0.9029
#
#
# Precision: 92%
#
# Recall: 91%
#
# f1_score:91%

# %% [markdown]
# ### 4.5.2 Arquitetura VGG16

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG16? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Assim como a resnet, as VGG determinam se uma imagem contém um determinado objeto.
# A VGG16 é composta por 16 camadas convolucionais, na arquitetura vejos que ela apenas convoluções 3x3, porém é compensada por muitos filtros.
#
# A rede foi treinada em 4GPUs por 2 a 3 semanas com base em nossas pesquisas.
#
# VGG16 no entanto, possui 138 milhões de parâmetros, o que a torna uma rede ruim para treinar a partir do zero. É interessante utiliza em um modelo sub treinado.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A VGG é construida com vários filtros pequenos. Nas nossas pesquisas entendemos que é possível usar até 512 filtros nas ultimas camadas, como mostra a imagem abaixo:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O maior ponto negativo é que é uma rede enorme, ou seja leva mais temppo para treino dos seus parâmetros.

# %%
conv_base = VGG16(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_6 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
# ...

# %%
optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit(train_generator, epochs=qtde_epocas, validation_steps=5, steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Epoch 1/7
# 5/5 [==============================] - 8s 1s/step - loss: 2.7589 - precision_score: 0.4295 - recall_score: 0.4150 - f1_score: 0.4221 - val_loss: 1.8204 - val_precision_score: 0.5556 - val_recall_score: 0.5375 - val_f1_score: 0.5462
# Epoch 2/7
# 5/5 [==============================] - 5s 1s/step - loss: 1.1719 - precision_score: 0.6460 - recall_score: 0.6125 - f1_score: 0.6288 - val_loss: 1.1146 - val_precision_score: 0.6789 - val_recall_score: 0.6562 - val_f1_score: 0.6672
# Epoch 3/7
# 5/5 [==============================] - 6s 1s/step - loss: 0.7002 - precision_score: 0.8142 - recall_score: 0.7750 - f1_score: 0.7938 - val_loss: 0.5374 - val_precision_score: 0.8330 - val_recall_score: 0.8125 - val_f1_score: 0.8225
# Epoch 4/7
# 5/5 [==============================] - 6s 1s/step - loss: 0.4504 - precision_score: 0.8540 - recall_score: 0.8375 - f1_score: 0.8456 - val_loss: 0.5446 - val_precision_score: 0.8105 - val_recall_score: 0.8000 - val_f1_score: 0.8052
# Epoch 5/7
# ...

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:
#
# Observamos que possuem valores parecidos com a resnet50, porém um pouco menor.
# Os calculos de precisão, sensibilidade e f1_score tendem a subir, tendo o mesmo pico em ambos, o mesmo pico aparece na perda o que justifica que na terceira época os valores decairam no treinamento.

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:
#
# 5/5 [==============================] - 7s 2s/step - loss: 0.2803 - precision_score: 0.9115 - recall_score: 0.8938 - f1_score: 0.9024 - val_loss: 0.3797 - val_precision_score: 0.8813 - val_recall_score: 0.8813 - val_f1_score: 0.8812
#
# Precision: 88%
#
# recall: 88%
#
# f1-score: 88%

# %% [markdown]
# ### 4.5.3 Arquitetura VGG19

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG19? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# É bem similar a VGG16, porém utiliza 19 camadas convolucionais.
# O lado ruim é que continua com uma arquitetura bem complexa e grande, o que um modelo pode demorar para rodar com a mesma. Um modelo pré treinado é um caso que essa rede funciona de forma agradável

# %%
conv_base = VGG19(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_7 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv4 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
# ...

# %%
optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit(train_generator, epochs=qtde_epocas, validation_steps=5, steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Epoch 1/7
# 5/5 [==============================] - 8s 2s/step - loss: 2.0863 - precision_score: 0.4920 - recall_score: 0.4563 - f1_score: 0.4731 - val_loss: 1.1840 - val_precision_score: 0.6052 - val_recall_score: 0.5625 - val_f1_score: 0.5825
# Epoch 2/7
# 5/5 [==============================] - 6s 1s/step - loss: 0.6461 - precision_score: 0.7645 - recall_score: 0.7563 - f1_score: 0.7603 - val_loss: 0.6703 - val_precision_score: 0.7657 - val_recall_score: 0.7563 - val_f1_score: 0.7609
# Epoch 3/7
# 5/5 [==============================] - 6s 1s/step - loss: 0.5245 - precision_score: 0.8225 - recall_score: 0.8125 - f1_score: 0.8173 - val_loss: 0.4524 - val_precision_score: 0.8528 - val_recall_score: 0.8375 - val_f1_score: 0.8450
# Epoch 4/7
# 5/5 [==============================] - 6s 1s/step - loss: 0.4840 - precision_score: 0.8487 - recall_score: 0.8388 - f1_score: 0.8436 - val_loss: 0.3934 - val_precision_score: 0.8483 - val_recall_score: 0.8375 - val_f1_score: 0.8427
# Epoch 5/7
# ...

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**
#
# Notamos que pelo aumento de convoluções os picos na terceira época diminuiram, porém ainda conseguimos tirar conclusões posítivas sobre o modelo e que não está enviesado, tirando overfitting e underfitting de nossas conclusões.

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:
#
# 5/5 [==============================] - 7s 2s/step - loss: 0.2881 - precision_score: 0.8938 - recall_score: 0.8938 - f1_score: 0.8937 - val_loss: 0.3635 - val_precision_score: 0.8728 - val_recall_score: 0.8625 - val_f1_score: 0.8676
#
# precision: 89%
#
# Recall: 86%
#
# f1-score: 86%

# %% [markdown]
# ## 4.6 Compartivo de arquiteturas
#
# Preencha a tabela abaixo com os valores dos indicadores de performance apresentados.
#
# _O cálculo do F1-Score é dado por 2 * (Precisão * Sensibilidade) / (Precisão + Sensibilidade)._

# %% [markdown]
# | Modelo   | Precisão (*Precision*) | Sensibilidade (*Recall*) | F1-Score |
# |----------|----------|---------------|----------|
# | ResNet50 | 92 %     | 91 %          | 91 %     |
# | VGG16    | 88 %     | 88 %          | 88 %     |
# | VGG19    | 89 %     | 86 %          | 86 %     |

# %% [markdown]
# ## 4.7 Conclusões
#
# Analise os resultados da tabela de indicadores do comparativo de arquiteturas e explique os principais motivos pelos quais cada modelo obteve cada resultado.

# %% [markdown]
# **Resposta**:
#
# A escolha até então seria a ResNet50, pelo fato de apresentar melhores métricas, escolhemos a mesma também devido a sensibilidade. Novamente citando, a sensibilidade é um fator importante, pois a gente entende que pacientes que estão bem não podem correr o risco de tratamento de algo que não possuem.
#
# A resnet tem uma arquitetura preparada para trabalhar com um grande número de camadas, acredito assim que pela sua performance na separação de features obteve um melhor resultado.
#
# Uma comparação interessante é entre as VGG's, a com mais convoluções apresentou um melhor resultado na precisão, mas na sensibilidade deixou a desejar, talvez isso explique que muitas vezes o número de filtros da VGG que ajudam a mesma a obter bons resultados, não apenas o aumento das convoluções.
#
#
# Comparações entre as redes até então estudadas:
#
# A VGG em um cenário real resolve problemas de classificação de imagens, porém a GoogLeNet e SqueezeNet são as preferidas. Para propósitos de aprendizado é direto ao ponto na implementação e possuí um numéro de filtros excelente.
# Para o caso de utilizar mais convoluções, é interessante usar a resnet, evitando assim o problema de fuga de gradiente. As resnets são menos complexas porém tem menos filtros comparados a VGG.

# %% [markdown]
# ## 4.8 Abordagem adicional (obrigatório)
#
# Considerando os outros classificadores, escolha outro que ainda não foi utilizado, implemente abaixo. Ao final compare os resultados e explique os resultados.
#
# _Não se esquece de utilizar as importações adequadas para cada modelo.
# A forma de implementação deve respeitar as mesmas condições como valor de split e quantidade de imagens para poder comparar os modelos._

# %%
#IMPLEMENTE
conv_base = ResNet152(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False



x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()


optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])


history = model.fit(train_generator, epochs=qtde_epocas, validation_steps=5, steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_8 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv1_pad (ZeroPadding2D)      (None, None, None,   0           ['input_8[0][0]']
#                                 3)
#
#  conv1_conv (Conv2D)            (None, None, None,   9472        ['conv1_pad[0][0]']
#                                 64)
#
#  conv1_bn (BatchNormalization)  (None, None, None,   256         ['conv1_conv[0][0]']
#                                 64)
#
#  conv1_relu (Activation)        (None, None, None,   0           ['conv1_bn[0][0]']
#                                 64)
#
#  pool1_pad (ZeroPadding2D)      (None, None, None,   0           ['conv1_relu[0][0]']
#                                 64)
#
# ...

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ### 4.8.1 Conclusões sobre a abordagem adicional
#
# Como seu modelo performou em comparação com os demais modelos anteriores? Justifique sua resposta levando em consideração a arquitetura respectiva.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# Nós executamos o modelo RestNet152, devido ao seu potencial de conseguir até 152 convoluções, e com uma arquitetura clara de se entender.
#
# Outro motivo foi por conta que comparamos duas VGG e agora vamos comparar as ResNets.
#
#
# 5/5 [==============================] - 6s 1s/step - loss: 0.2214 - precision_score: 0.9244 - recall_score: 0.9187 - f1_score: 0.9215 - val_loss: 0.2405 - val_precision_score: 0.8996 - val_recall_score: 0.8938 - val_f1_score: 0.8966
#
#
# Assim como a VGG, a resnet com maiores convoluções não trouxe melhores métricas. Nossa conclusão diante disso é devido a quantidade de dados e épocas que estamos executando, se fosse algo que abrangesse mais itens, sem dúvidas a rede seria mais pperformática. O nosso modelo teve um ótimo resultado, porém de todos os executados a ResNet50 seria nossa principal escolha.
